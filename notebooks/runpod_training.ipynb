# %% [markdown]
# # Notebook para ejecución de entrenamientos en Runpod

# %% [markdown]
# ## Acceso al directorio del proyecto

# %%
# %cd bgc-infiller/

# %% [markdown]
# ## Instalación de las dependencias en el Pod

# %%
# %pip install -r requirements.txt

# %% [markdown]
# ## Establecer WANDB_API_KEY y ruta de Python a la raíz del proyecto

# %%
import os

os.environ["WANDB_API_KEY"] = "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"
os.environ["PYTHONPATH"] = "."

# %% [markdown]
# ## Ejecución de los pipelines de entrenamiento

# %%
# !MAIN_CONFIG="config/main_config.yaml" python3 ./src/main.py
